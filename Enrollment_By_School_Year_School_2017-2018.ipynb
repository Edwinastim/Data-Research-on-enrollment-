# %% [markdown]
# # Data Research on Enrollment by School Year (Schools) From 2017 - 2018 in the State of Massachusetts
# ## Team Members: Edwin Asitimbay, Daniela Bautista, John Lee

# %% [markdown]
# # Data Loading

# %%
#Import and data loading
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

df = pd.read_csv('tabular.educ_enrollment_by_year_schools_2017-18.csv')

pd.options.display.max_columns = 60

df
# Out:
#       seq_id    schid                                      name     municipal  \
# 0      22265  4450105  Abby Kelley Foster Charter Public School     Worcester
# 1      22266    10001          Abington Early Education Program     Abington
# 2      22267    10505                             Abington High      Abington
# 3      22268    10405                    Abington Middle School      Abington
# 4      22269    10020                   Beaver Brook Elementary     Abington
# ...      ...      ...                                       ...           ...
# 1845   24110  3480605                  Worcester Technical High     Worcester
# 1846   24111  3490010                             R. H. Conwell  Worthington
# 1847   24112  3500010                        Charles E Roderick      Wrentham
# 1848   24113  3500003                                   Delaney      Wrentham
# 1849   24114        0                              State Totals  State Totals
#
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Renaming Column Names

# %%
#Data cleaning by renaming columns so it is understandable.
df.rename(columns = {'seq_id':'Seq ID',
                     'schid':'School ID',
                     'name':'School Name',
                     'municipal':'Municipal',
                     'schoolyear':'School Year',
                     'enrolled':'Enrolled',
                     'grade_pk':'Enrollment in Pre-Kindergarden',
                     'grade_k':'Enrollment in Kindergarden',
                     'grade_1':'Enrollment in Grade 1',
                     'grade_2':'Enrollment in Grade 2',
                     'grade_3':'Enrollment in Grade 3',
                     'grade_4':'Enrollment in Grade 4',
                     'grade_5':'Enrollment in Grade 5',
                     'grade_6':'Enrollment in Grade 6',
                     'grade_7':'Enrollment in Grade 7',
                     'grade_8':'Enrollment in Grade 8',
                     'grade_9':'Enrollment in Grade 9',
                     'grade_10':'Enrollment in Grade 10',
                     'grade_11':'Enrollment in Grade 11',
                     'grade_12':'Enrollment in Grade 12',
                     'grade_sp':'Enrollment in Special Education',
                     'aa_num':'African American or Black Enrollment',
                     'aa_pct':'%African American or Black Enrollment',
                     'as_num':'Asian Enrollment',
                     'as_pct':'%Asian Enrollment',
                     'lat_num':'Hispanic or Latino Enrollment',
                     'lat_pct':'%Hispanic or Latino Enrollment',
                     'whi_num':'White Enrollment',
                     'whi_pct':'%White Enrollment',
                     'na_num':'Native American Enrollment',
                     'na_pct':'%Native American Enrollment',
                     'pi_num':'Native Hawaiian or Other Pacific Islander Enrollment',
                     'pi_pct':'%Native Hawaiian or Other Pacific Islander Enrollment',
                     'mult_num':'Multi-Race Non-Hispanic Enrollment',
                     'mult_pct':'%Multi-Race Non-Hispanic Enrollment',
                     'male_num':'Male Enrollment',
                     'male_pct':'%Male Enrollment',
                     'fem_num':'Female Enrollment',
                     'fem_pct':'%Female Enrollment',
                     'ell_num':'Limited English Proficient/First Language Not English Enrollment',
                     'ell_pct':'%Limited English Proficient/First Language Not English Enrollment',
                     'lep_num':'Firat Language not English Enrollment',
                     'lep_pct':'%First Language not English Enrollment',
                     'swd_num':'Students with Disabilities Enrollment',
                     'swd_pct':'%Students with Disabilities Enrollment',
                     'li_num':'Low-income Enrollment',
                     'li_pct':'%Low-income Enrollment',
                     'free_num':'Student Eligible for Free Lunch Enrollment',
                     'free_pct':'%Student Eligible for Free Lunch Enrollment',
                     'red_num':'Student Eligible for Reduced Price Lunch Enrollment',
                     'red_pct':'%Student Eligible for Reduced Price Lunch Enrollment',
                     'hn_num':'High Needs Enrollment',
                     'hn_pct':'%High Needs Enrollment'}, inplace = True)
df
# Out:
#       Seq ID  School ID                               School Name  \
# 0      22265    4450105  Abby Kelley Foster Charter Public School
# 1      22266      10001          Abington Early Education Program
# 2      22267      10505                             Abington High
# 3      22268      10405                    Abington Middle School
# 4      22269      10020                   Beaver Brook Elementary
# ...      ...        ...                                       ...
# 1845   24110    3480605                  Worcester Technical High
# 1846   24111    3490010                             R. H. Conwell
# 1847   24112    3500010                        Charles E Roderick
# 1848   24113    3500003                                   Delaney
# 1849   24114          0                              State Totals
#
#          Municipal School Year  Enrolled  Enrollment in Pre-Kindergarden  \
# 0        Worcester     2017-18      1425                               0
# ...

# %% [markdown]
# ### Removing Unnecessary Data

# %%
#Drop these columns as they are useless. Most of these are empty and were
#never recorded. Percentage is pointless as the important values are mostly
#recorded as numbers. 'ed_num' and 'ed_pct' are dropped because we have no
#information on what they represents, so removing it will avoid confusion.
#This is why the values of 'Enrolled' must be updated with the difference
#of 'Enrolled' and 'ed_num'.
df.drop(['Seq ID',
        '%African American or Black Enrollment',
        '%Asian Enrollment',
        '%Hispanic or Latino Enrollment',
        '%White Enrollment',
        '%Native American Enrollment',
        '%Native Hawaiian or Other Pacific Islander Enrollment',
        '%Multi-Race Non-Hispanic Enrollment',
        '%Male Enrollment',
        '%Female Enrollment',
        '%Limited English Proficient/First Language Not English Enrollment',
        '%First Language not English Enrollment',
        '%Students with Disabilities Enrollment',
        'Low-income Enrollment',
        '%Low-income Enrollment',
        'Student Eligible for Free Lunch Enrollment',
        '%Student Eligible for Free Lunch Enrollment',
        'Student Eligible for Reduced Price Lunch Enrollment',
        '%Student Eligible for Reduced Price Lunch Enrollment',
        '%High Needs Enrollment',
        'ed_num',
        'ed_pct'], axis = 1, inplace = True)
df
# Out:
#       School ID                               School Name     Municipal  \
# 0       4450105  Abby Kelley Foster Charter Public School     Worcester
# 1         10001          Abington Early Education Program     Abington
# 2         10505                             Abington High      Abington
# 3         10405                    Abington Middle School      Abington
# 4         10020                   Beaver Brook Elementary     Abington
# ...         ...                                       ...           ...
# 1845    3480605                  Worcester Technical High     Worcester
# 1846    3490010                             R. H. Conwell  Worthington
# 1847    3500010                        Charles E Roderick      Wrentham
# 1848    3500003                                   Delaney      Wrentham
# 1849          0                              State Totals  State Totals
#
#      School Year  Enrolled  Enrollment in Pre-Kindergarden  \
# ...

# %% [markdown]
# # Organizing
#
# ### Sorting the Dataset

# %%
#Set the index to be on 'School Name' and sort the values of 'School Name' in
#ascending order.
df.set_index('School Name', inplace = True)
df.sort_values('School Name', inplace = True)
df
# Out:
#                                  School ID         Municipal School Year  \
# School Name
# 1 LT Charles W. Whitcomb School    1700045       Marlborough     2017-18
# 21st Century Skills Academy        3320515  West Springfield     2017-18
# A Drewicz Elementary               1630016              Lynn     2017-18
# A E Angier                         2070005            Newton     2017-18
# A F Maloney                        6220015        Blackstone     2017-18
# ...                                    ...               ...         ...
# Worcester East Middle              3480420         Worcester     2017-18
# Worcester Technical High           3480605         Worcester     2017-18
# Wyman                              3470060            Woburn     2017-18
# Young Achievers                     350380            Boston     2017-18
# Zervas                             2070130            Newton     2017-18
#
#                                  Enrolled  Enrollment in Pre-Kindergarden  \
# ...

# %% [markdown]
# ## Making a different dataframe in order to derive stats
# ### Removed the Final Total from df1 but not from the original dataframe

# %%
df1 = df
df1 = df1.drop('State Totals')
df1
# Out:
#                                  School ID         Municipal School Year  \
# School Name
# 1 LT Charles W. Whitcomb School    1700045       Marlborough     2017-18
# 21st Century Skills Academy        3320515  West Springfield     2017-18
# A Drewicz Elementary               1630016              Lynn     2017-18
# A E Angier                         2070005            Newton     2017-18
# A F Maloney                        6220015        Blackstone     2017-18
# ...                                    ...               ...         ...
# Worcester East Middle              3480420         Worcester     2017-18
# Worcester Technical High           3480605         Worcester     2017-18
# Wyman                              3470060            Woburn     2017-18
# Young Achievers                     350380            Boston     2017-18
# Zervas                             2070130            Newton     2017-18
#
#                                  Enrolled  Enrollment in Pre-Kindergarden  \
# ...

# %% [markdown]
# # Data Analysis using Descriptive Statistics
# ### Enrolled

# %%
mean = df1['Enrolled'].mean()
median = df1['Enrolled'].median()
dmax = df1['Enrolled'].max()
dmin = df1['Enrolled'].min()
std = df1['Enrolled'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  515.9724175229854
# Median:  436.0
# Max:  4123
# Min:  1
# Std:  369.95465352846526

# %%
#The school(s) with the lowest enrollment.

df1[df1['Enrolled'] == 1]
# Out:
#                                      School ID    Municipal School Year  \
# School Name
# Fall River Gateway to College @ BCC     950515  Fall River      2017-18
# Landmark School                         300920    Rockport      2017-18
# Solstice School                        2540810    Rockport      2017-18
#
#                                      Enrolled  Enrollment in Pre-Kindergarden  \
# School Name
# Fall River Gateway to College @ BCC         1                               0
# Landmark School                             1                               0
# Solstice School                             1                               0
#
#                                      Enrollment in Kindergarden  \
# School Name
# Fall River Gateway to College @ BCC                           0
# Landmark School                                               0
# Solstice School                                               0
#
# ...

# %%
#The school(s) with the highest enrollment.

df1[df1['Enrolled'] == 4123]
# Out:
#                School ID Municipal School Year  Enrolled  \
# School Name
# Brockton High     440505  Brockton     2017-18      4123
#
#                Enrollment in Pre-Kindergarden  Enrollment in Kindergarden  \
# School Name
# Brockton High                               0                           0
#
#                Enrollment in Grade 1  Enrollment in Grade 2  \
# School Name
# Brockton High                      0                      0
#
#                Enrollment in Grade 3  Enrollment in Grade 4  \
# School Name
# Brockton High                      0                      0
#
#                Enrollment in Grade 5  Enrollment in Grade 6  \
# School Name
# Brockton High                      0                      0
#
#                Enrollment in Grade 7  Enrollment in Grade 8  \
# School Name
# Brockton High                      0                      0
#
#                Enrollment in Grade 9  Enrollment in Grade 10  \
# School Name
# ...

# %% [markdown]
# ### Enrollment in Pre-Kindergarden

# %%
# Enrollment in Pre-Kindergarden
mean = df1['Enrollment in Pre-Kindergarden'].mean()
median = df1['Enrollment in Pre-Kindergarden'].median()
dmax = df1['Enrollment in Pre-Kindergarden'].max()
dmin = df1['Enrollment in Pre-Kindergarden'].min()
std = df1['Enrollment in Pre-Kindergarden'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  16.50730124391563
# Median:  0.0
# Max:  529
# Min:  0
# Std:  38.73626101525821

# %% [markdown]
# ### Enrollment in Kindergarden

# %%
# Enrollment in Kindergarden
mean = df1['Enrollment in Kindergarden'].mean()
median = df1['Enrollment in Kindergarden'].median()
dmax = df1['Enrollment in Kindergarden'].max()
dmin = df1['Enrollment in Kindergarden'].min()
std = df1['Enrollment in Kindergarden'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  35.702541914548405
# Median:  19.0
# Max:  513
# Min:  0
# Std:  44.47632035746117

# %% [markdown]
# ### Enrollment in Grade 1

# %%
mean = df1['Enrollment in Grade 1'].mean()
median = df1['Enrollment in Grade 1'].median()
dmax = df1['Enrollment in Grade 1'].max()
dmin = df1['Enrollment in Grade 1'].min()
std = df1['Enrollment in Grade 1'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  36.79772850189291
# Median:  24.0
# Max:  256
# Min:  0
# Std:  42.74962564365946

# %% [markdown]
# ### Enrollment in Grade 2

# %%
mean = df1['Enrollment in Grade 2'].mean()
median = df1['Enrollment in Grade 2'].median()
dmax = df1['Enrollment in Grade 2'].max()
dmin = df1['Enrollment in Grade 2'].min()
std = df1['Enrollment in Grade 2'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  36.91130340724716
# Median:  22.0
# Max:  255
# Min:  0
# Std:  43.225770518088204

# %% [markdown]
# ### Enrollment in Grade 3

# %%
mean = df1['Enrollment in Grade 3'].mean()
median = df1['Enrollment in Grade 3'].median()
dmax = df1['Enrollment in Grade 3'].max()
dmin = df1['Enrollment in Grade 3'].min()
std = df1['Enrollment in Grade 3'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  37.8939967550027
# Median:  21.0
# Max:  324
# Min:  0
# Std:  44.92205384589751

# %% [markdown]
# ### Enrollment in Grade 4

# %%
mean = df1['Enrollment in Grade 4'].mean()
median = df1['Enrollment in Grade 4'].median()
dmax = df1['Enrollment in Grade 4'].max()
dmin = df1['Enrollment in Grade 4'].min()
std = df1['Enrollment in Grade 4'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  39.02866414277988
# Median:  14.0
# Max:  424
# Min:  0
# Std:  48.93161298537852

# %% [markdown]
# ### Enrollment in Grade 5

# %%
mean = df1['Enrollment in Grade 5'].mean()
median = df1['Enrollment in Grade 5'].median()
dmax = df1['Enrollment in Grade 5'].max()
dmin = df1['Enrollment in Grade 5'].min()
std = df1['Enrollment in Grade 5'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  39.203353163872364
# Median:  0.0
# Max:  464
# Min:  0
# Std:  56.06168110498768

# %% [markdown]
# ### Enrollment in Grade 6

# %%
mean = df1['Enrollment in Grade 6'].mean()
median = df1['Enrollment in Grade 6'].median()
dmax = df1['Enrollment in Grade 6'].max()
dmin = df1['Enrollment in Grade 6'].min()
std = df1['Enrollment in Grade 6'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  38.540832882639265
# Median:  0.0
# Max:  503
# Min:  0
# Std:  76.44578040358793

# %% [markdown]
# ### Enrollment in Grade 7

# %%
mean = df1['Enrollment in Grade 7'].mean()
median = df1['Enrollment in Grade 7'].median()
dmax = df1['Enrollment in Grade 7'].max()
dmin = df1['Enrollment in Grade 7'].min()
std = df1['Enrollment in Grade 7'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  38.36019469983775
# Median:  0.0
# Max:  493
# Min:  0
# Std:  80.64077829880645

# %% [markdown]
# ### Enrollment in Grade 8

# %%
mean = df1['Enrollment in Grade 8'].mean()
median = df1['Enrollment in Grade 8'].median()
dmax = df1['Enrollment in Grade 8'].max()
dmin = df1['Enrollment in Grade 8'].min()
std = df1['Enrollment in Grade 8'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  38.922660897782585
# Median:  0.0
# Max:  693
# Min:  0
# Std:  82.90801617031168

# %% [markdown]
# ### Enrollment in Grade 9

# %%
mean = df1['Enrollment in Grade 9'].mean()
median = df1['Enrollment in Grade 9'].median()
dmax = df1['Enrollment in Grade 9'].max()
dmin = df1['Enrollment in Grade 9'].min()
std = df1['Enrollment in Grade 9'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  41.400757166035696
# Median:  0.0
# Max:  1143
# Min:  0
# Std:  107.6542385882059

# %% [markdown]
# ### Enrollment in Grade 10

# %%
mean = df1['Enrollment in Grade 10'].mean()
median = df1['Enrollment in Grade 10'].median()
dmax = df1['Enrollment in Grade 10'].max()
dmin = df1['Enrollment in Grade 10'].min()
std = df1['Enrollment in Grade 10'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  39.43915630070308
# Median:  0.0
# Max:  1022
# Min:  0
# Std:  102.880461159858

# %% [markdown]
# ### Enrollment in Grade 11

# %%
mean = df1['Enrollment in Grade 11'].mean()
median = df1['Enrollment in Grade 11'].median()
dmax = df1['Enrollment in Grade 11'].max()
dmin = df1['Enrollment in Grade 11'].min()
std = df1['Enrollment in Grade 11'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  38.77068685776095
# Median:  0.0
# Max:  992
# Min:  0
# Std:  100.24064327665343

# %% [markdown]
# ### Enrollment in Grade 12

# %%
mean = df1['Enrollment in Grade 12'].mean()
median = df1['Enrollment in Grade 12'].median()
dmax = df1['Enrollment in Grade 12'].max()
dmin = df1['Enrollment in Grade 12'].min()
std = df1['Enrollment in Grade 12'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  37.846403461330446
# Median:  0.0
# Max:  950
# Min:  0
# Std:  97.79298409052014

# %% [markdown]
# ### Enrollment in Grade Special Education

# %%
mean = df1['Enrollment in Special Education'].mean()
median = df1['Enrollment in Special Education'].median()
dmax = df1['Enrollment in Special Education'].max()
dmin = df1['Enrollment in Special Education'].min()
std = df1['Enrollment in Special Education'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  0.6468361276365603
# Median:  0.0
# Max:  92
# Min:  0
# Std:  3.547176182511453

# %% [markdown]
# ### African American or Black Enrollment

# %%
mean = df1['African American or Black Enrollment'].mean()
median = df1['African American or Black Enrollment'].median()
dmax = df1['African American or Black Enrollment'].max()
dmin = df1['African American or Black Enrollment'].min()
std = df1['African American or Black Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  46.68036776636019
# Median:  15.0
# Max:  2573
# Min:  0
# Std:  104.39496393139359

# %% [markdown]
# ### Asian Enrollment

# %%
mean = df1['Asian Enrollment'].mean()
median = df1['Asian Enrollment'].median()
dmax = df1['Asian Enrollment'].max()
dmin = df1['Asian Enrollment'].min()
std = df1['Asian Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  35.51433207138994
# Median:  12.0
# Max:  1000
# Min:  0
# Std:  68.83057604117685

# %% [markdown]
# ### Hispanic or Latino Enrollment

# %%
mean = df1['Hispanic or Latino Enrollment'].mean()
median = df1['Hispanic or Latino Enrollment'].median()
dmax = df1['Hispanic or Latino Enrollment'].max()
dmin = df1['Hispanic or Latino Enrollment'].min()
std = df1['Hispanic or Latino Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  103.40941049215792
# Median:  38.0
# Max:  3083
# Min:  0
# Std:  170.50944019938873

# %% [markdown]
# ### White Enrollment

# %%
mean = df1['White Enrollment'].mean()
median = df1['White Enrollment'].median()
dmax = df1['White Enrollment'].max()
dmin = df1['White Enrollment'].min()
std = df1['White Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  310.0746349378042
# Median:  259.0
# Max:  1879
# Min:  1
# Std:  262.84250969506854

# %% [markdown]
# ### Native American Enrollment

# %%
mean = df1['Native American Enrollment'].mean()
median = df1['Native American Enrollment'].median()
dmax = df1['Native American Enrollment'].max()
dmin = df1['Native American Enrollment'].min()
std = df1['Native American Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  1.1384532179556517
# Median:  0.0
# Max:  33
# Min:  0
# Std:  2.3549427590449636

# %% [markdown]
# ### Native Hawaiian or Other Pacific Islander Enrollment

# %%
mean = df1['Native Hawaiian or Other Pacific Islander Enrollment'].mean()
median = df1['Native Hawaiian or Other Pacific Islander Enrollment'].median()
dmax = df1['Native Hawaiian or Other Pacific Islander Enrollment'].max()
dmin = df1['Native Hawaiian or Other Pacific Islander Enrollment'].min()
std = df1['Native Hawaiian or Other Pacific Islander Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  0.4434829637641969
# Median:  0.0
# Max:  10
# Min:  0
# Std:  0.9804208748472627

# %% [markdown]
# ### Multi-Race Non-Hispanic Enrollment

# %%
mean = df1['Multi-Race Non-Hispanic Enrollment'].mean()
median = df1['Multi-Race Non-Hispanic Enrollment'].median()
dmax = df1['Multi-Race Non-Hispanic Enrollment'].max()
dmin = df1['Multi-Race Non-Hispanic Enrollment'].min()
std = df1['Multi-Race Non-Hispanic Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  18.714440237966468
# Median:  14.0
# Max:  181
# Min:  0
# Std:  17.102524187221142

# %% [markdown]
# ### Male Enrollment

# %%
mean = df1['Male Enrollment'].mean()
median = df1['Male Enrollment'].median()
dmax = df1['Male Enrollment'].max()
dmin = df1['Male Enrollment'].min()
std = df1['Male Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  264.5575987020011
# Median:  225.0
# Max:  2140
# Min:  0
# Std:  187.62354964922505

# %% [markdown]
# ### Female Enrollment

# %%
mean = df1['Female Enrollment'].mean()
median = df1['Female Enrollment'].median()
dmax = df1['Female Enrollment'].max()
dmin = df1['Female Enrollment'].min()
std = df1['Female Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  251.35478637101136
# Median:  211.0
# Max:  1983
# Min:  0
# Std:  184.30679072171134

# %% [markdown]
# ### Limited English Proficient/First Language Not English Enrollment

# %%
'Limited English Proficient/First Language Not English Enrollment'
mean = df1['Limited English Proficient/First Language Not English Enrollment'].mean()
median = df1['Limited English Proficient/First Language Not English Enrollment'].median()
dmax = df1['Limited English Proficient/First Language Not English Enrollment'].max()
dmin = df1['Limited English Proficient/First Language Not English Enrollment'].min()
std = df1['Limited English Proficient/First Language Not English Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  52.64088696592753
# Median:  18.0
# Max:  1121
# Min:  0
# Std:  86.31962510345315

# %% [markdown]
# ### First Language not English Enrollment

# %%
'Firat Language not English Enrollment'
mean = df1['Firat Language not English Enrollment'].mean()
median = df1['Firat Language not English Enrollment'].median()
dmax = df1['Firat Language not English Enrollment'].max()
dmin = df1['Firat Language not English Enrollment'].min()
std = df1['Firat Language not English Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  107.99242833964306
# Median:  44.0
# Max:  2744
# Min:  0
# Std:  172.13516204396768

# %% [markdown]
# ### Students with Disabilities Enrollment

# %%
'Students with Disabilities Enrollment'
mean = df1['Students with Disabilities Enrollment'].mean()
median = df1['Students with Disabilities Enrollment'].median()
dmax = df1['Students with Disabilities Enrollment'].max()
dmin = df1['Students with Disabilities Enrollment'].min()
std = df1['Students with Disabilities Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  86.84207679826933
# Median:  70.0
# Max:  535
# Min:  0
# Std:  62.13328731917521

# %% [markdown]
# ### High needs Enrollment

# %%
mean = df1['High Needs Enrollment'].mean()
median = df1['High Needs Enrollment'].median()
dmax = df1['High Needs Enrollment'].max()
dmin = df1['High Needs Enrollment'].min()
std = df1['High Needs Enrollment'].std()
print('Mean: ', mean)
print('Median: ', median)
print('Max: ', dmax)
print('Min: ', dmin)
print('Std: ', std)
# Out:
# Mean:  237.47593293672256
# Median:  177.0
# Max:  2665
# Min:  0
# Std:  214.78462631885603

# %% [markdown]
# # Data Visualization
#
# ## Number of Students Enrolled vs School Names by a Municipal

# %%
#Compare all schools' enrollment that are from Acton.

df2 = df1[df1['Municipal'] == 'Acton']['Enrolled']
df2
# Out:
# School Name
# Acton-Boxborough Regional High    1827
# Blanchard Memorial School          447
# C.T. Douglas Elementary School     427
# Luther Conant School               442
# McCarthy-Towne School              487
# Merriam School                     498
# Paul P Gates Elementary School     402
# Raymond J Grey Junior High         964
# Name: Enrolled, dtype: int64

# %%
df2.plot.bar(title = "Students Enrolled in Schools of Acton, Massachusetts, of 2017-2018", rot = 70)
plt.ylabel("Number of Students")
# Out:
# Text(0, 0.5, 'Number of Students')
